# %% [markdown]
# # Skapa vmodel och model på senaste datat utan test

# %%
import pandas as pd
from datetime import datetime as dt
import yfinance as yf
import matplotlib.pyplot as plt 
from catboost import CatBoostRegressor,Pool,utils
import time
plt.style.use('fivethirtyeight')
pd.set_option('display.width',200)

# %%
def set_kolumner():
    rkolumner = ['vol_y', 'ret_2', 'vol_2', 'ret_3', 'vol_3', 'ret_4', 'vol_4', 'ret_5', 'vol_5', 
                'ret_6', 'vol_6', 'ret_7', 'vol_7', 'ret_8', 'vol_8', 'ret_9', 'vol_9', 'ret_10', 
                'vol_10', 'year', 'month', 'wday', 'day']
    vkolumner = rkolumner[1:]
    
    return vkolumner, rkolumner

# %% [markdown]
# # let the data include vol_y as input to ret_y-training

# %%
def fit_data(train, iterations=550):
    
    vkolumner, rkolumner = set_kolumner()
    
    ret_y=train.ret_y
    vol_y=train.vol_y

    print('shape train av ret_y',train[rkolumner].shape)   
    print('shape train av vol_y',train[vkolumner].shape)   
    
    vmodel = CatBoostRegressor(iterations=iterations,
        verbose=False, random_state=2021)
    
    vmodel.fit(train[vkolumner],y=vol_y,use_best_model=False) # train on 'kolumner' except vol_y and ret_y
    
    model = CatBoostRegressor(iterations=iterations,
        verbose=False, random_state=2021)
    
    model.fit(train[rkolumner],y=ret_y,use_best_model=False) # includes vol_y for training
    
    return vmodel, model

# %%
def full_model( data):
    # data = data.tail(725)  # använd de 725 sista dagarna (2 år)
    vmodel, model = fit_data(data)
    print(data.shape)
    return vmodel,model

def pct_change(df, ny, gammal, dagar):
    df[ny+'_'+str(dagar)] = df[gammal].pct_change(dagar)

# Historik för proc utveckling av 'Adj Close' och volume
def add_history(df):
    for i in range (10):
        pct_change(df,'ret','Adj Close',i+1)
        pct_change(df,'vol','Volume',i+1)
    
    df.rename(columns={'vol_1':'vol_y', 'ret_1':'ret_y'},inplace=True)
    df = df.dropna()
    return df

# kolumner för år, månad, dag samt predict
def add_more_cols(df):
    df['pred_Volume'] = None
    df['pred_AdjClose'] = None
        
    df['year']=pd.DatetimeIndex(df.index).year
    df['month']=pd.DatetimeIndex(df.index).month
    df['wday']=pd.DatetimeIndex(df.index).weekday
    df['day']=pd.DatetimeIndex(df.index).day
   
    return df

# %% [markdown]
# ## skapa alla modellerna

# %%
tickers = ['ETH-USD','BTC-USD','BCH-USD','ZRX-USD','XRP-USD',]

for ticker in tickers:
    print()
    df = yf.download([ticker], progress=True)[['Adj Close','Volume']]
    # df = df.iloc[-725:]
    df=add_history(df.copy())
    df=add_more_cols(df.copy())
    print(ticker,df.shape)

    vmodel, model = full_model(df)
    vmodel.save_model(f'{ticker[:3]}_vmodel')
    model.save_model(f'{ticker[:3]}_model')
    
    # Alternativa modeller
    df2=df.copy()
    for day in range(5):
        df2[['ret_y','vol_y']] = df2[['ret_y','vol_y']].shift(-1) 
        df2=df2.iloc[:-1,:]
        print(ticker,df2.shape)
        vmodel, model = full_model(df2)
        vmodel.save_model(f'{ticker[:3]}{day+1}_vmodel')
        model.save_model(f'{ticker[:3]}{day+1}_model')
# Out:
# [*********************100%***********************]  1 of 1 completed
# ETH-USD (1527, 28)
# shape train av ret_y (1527, 23)
# shape train av vol_y (1527, 22)
# (1527, 28)
# ETH-USD (1526, 28)
# shape train av ret_y (1526, 23)
# shape train av vol_y (1526, 22)
# (1526, 28)
# ETH-USD (1525, 28)
# shape train av ret_y (1525, 23)
# shape train av vol_y (1525, 22)
# (1525, 28)
# ETH-USD (1524, 28)
# shape train av ret_y (1524, 23)
# shape train av vol_y (1524, 22)
# (1524, 28)
# ETH-USD (1523, 28)
# shape train av ret_y (1523, 23)
# shape train av vol_y (1523, 22)
# (1523, 28)
# ETH-USD (1522, 28)
# shape train av ret_y (1522, 23)
# shape train av vol_y (1522, 22)
# (1522, 28)
#
# [*********************100%***********************]  1 of 1 completed
# BTC-USD (2676, 28)
# shape train av ret_y (2676, 23)
# shape train av vol_y (2676, 22)
# (2676, 28)
# BTC-USD (2675, 28)
# shape train av ret_y (2675, 23)
# shape train av vol_y (2675, 22)
# (2675, 28)
# BTC-USD (2674, 28)
# shape train av ret_y (2674, 23)
# shape train av vol_y (2674, 22)
# (2674, 28)
# BTC-USD (2673, 28)
# shape train av ret_y (2673, 23)
# shape train av vol_y (2673, 22)
# (2673, 28)
# BTC-USD (2672, 28)
# shape train av ret_y (2672, 23)
# shape train av vol_y (2672, 22)
# (2672, 28)
# BTC-USD (2671, 28)
# shape train av ret_y (2671, 23)
# shape train av vol_y (2671, 22)
# (2671, 28)
#
# [*********************100%***********************]  1 of 1 completed
# BCH-USD (1527, 28)
# shape train av ret_y (1527, 23)
# shape train av vol_y (1527, 22)
# (1527, 28)
# BCH-USD (1526, 28)
# shape train av ret_y (1526, 23)
# shape train av vol_y (1526, 22)
# (1526, 28)
# BCH-USD (1525, 28)
# shape train av ret_y (1525, 23)
# shape train av vol_y (1525, 22)
# (1525, 28)
# BCH-USD (1524, 28)
# shape train av ret_y (1524, 23)
# shape train av vol_y (1524, 22)
# (1524, 28)
# BCH-USD (1523, 28)
# shape train av ret_y (1523, 23)
# shape train av vol_y (1523, 22)
# (1523, 28)
# BCH-USD (1522, 28)
# shape train av ret_y (1522, 23)
# shape train av vol_y (1522, 22)
# (1522, 28)
#
# [*********************100%***********************]  1 of 1 completed
# ZRX-USD (1595, 28)
# shape train av ret_y (1595, 23)
# shape train av vol_y (1595, 22)
# (1595, 28)
# ZRX-USD (1594, 28)
# shape train av ret_y (1594, 23)
# shape train av vol_y (1594, 22)
# (1594, 28)
# ZRX-USD (1593, 28)
# shape train av ret_y (1593, 23)
# shape train av vol_y (1593, 22)
# (1593, 28)
# ZRX-USD (1592, 28)
# shape train av ret_y (1592, 23)
# shape train av vol_y (1592, 22)
# (1592, 28)
# ZRX-USD (1591, 28)
# shape train av ret_y (1591, 23)
# shape train av vol_y (1591, 22)
# (1591, 28)
# ZRX-USD (1590, 28)
# shape train av ret_y (1590, 23)
# shape train av vol_y (1590, 22)
# (1590, 28)
#
# [*********************100%***********************]  1 of 1 completed
# XRP-USD (1527, 28)
# shape train av ret_y (1527, 23)
# shape train av vol_y (1527, 22)
# (1527, 28)
# XRP-USD (1526, 28)
# shape train av ret_y (1526, 23)
# shape train av vol_y (1526, 22)
# (1526, 28)
# XRP-USD (1525, 28)
# shape train av ret_y (1525, 23)
# shape train av vol_y (1525, 22)
# (1525, 28)
# XRP-USD (1524, 28)
# shape train av ret_y (1524, 23)
# shape train av vol_y (1524, 22)
# (1524, 28)
# XRP-USD (1523, 28)
# shape train av ret_y (1523, 23)
# shape train av vol_y (1523, 22)
# (1523, 28)
# XRP-USD (1522, 28)
# shape train av ret_y (1522, 23)
# shape train av vol_y (1522, 22)
# (1522, 28)
